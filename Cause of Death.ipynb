# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('/content/cause_of_deaths.csv')

# %%
#key_questions
# According to cuase of death
#what is the most thing causes death ?
#what is the least thing causes death ?

#According to year
#what is the highest year in death?
#what is the lowest year in death?
#what is the highest year in death in each country?

#according to country
#what is the country with most deaths?
#what is the country with least deaths?
#whatis the most common cause of death in each country?

# %%
#used info function to know column name,count and its data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
#sample function to take random look on data
df.sample(5)
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 5673            Tuvalu  TUV  1993           1
# 393            Bahrain  BHR  2010           3
# 466           Barbados  BRB  2006           3
# 4996           Somalia  SOM  1997        2663
# 149            Andorra  AND  2019           0
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 5673                                        1                    1
# 393                                        38                   13
# 466                                        80                   21
# 4996                                      197                   58
# 149                                        36                    7
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 5673                         1        0         1                       1
# 393                          4        0        12                      35
# ...

# %%
# isnull().sum() function to know sum of null values each row
df.isnull().sum()
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
# To know how many time each country repeated
df['Country/Territory'].value_counts()
# Out:
# Country/Territory
# Afghanistan         30
# Papua New Guinea    30
# Niue                30
# North Korea         30
# North Macedonia     30
#                     ..
# Greenland           30
# Grenada             30
# Guam                30
# Guatemala           30
# Zimbabwe            30
# Name: count, Length: 204, dtype: int64

# %%
# Nervous system disease
'''
 Meningitis
 Alzheimer's Disease and Other Dementias
 Parkinson's Disease
 Drug Use Disorders	'''

Nervous_system_disease=df[['Country/Territory','Year','Meningitis',"Alzheimer's Disease and Other Dementias","Parkinson's Disease",'Drug Use Disorders']]
Nervous_system_disease.sample(10)
# Out:
#      Country/Territory  Year  Meningitis  \
# 3597           Morocco  2017         439
# 913           Cambodia  2003         567
# 2008           Georgia  2018          22
# 484            Belarus  2011          72
# 2286            Guyana  1996          16
# 553             Belize  2003           3
# 1230      Cook Islands  1990           0
# 3022           Liberia  2012         695
# 3537          Mongolia  2017          25
# 6108          Zimbabwe  2008        1720
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 3597                                     4808                 1320
# 913                                       818                  209
# 2008                                     1708                  309
# 484                                      3022                  648
# 2286                                       46                   16
# 553                                        24                    6
# ...

# %%
# respiratory disease
'''
Tuberculosis
Lower Respiratory Infections
Chronic Respiratory Diseases '''

respiratory_disease=df[['Country/Territory','Year',"Tuberculosis","Lower Respiratory Infections","Chronic Respiratory Diseases"]]
respiratory_disease.sample(10)
# Out:
#       Country/Territory  Year  Tuberculosis  Lower Respiratory Infections  \
# 5615             Turkey  1995          4061                         24121
# 3049              Libya  2005            59                           567
# 1946              Gabon  2016           518                           688
# 3296              Malta  2016             1                           175
# 2125          Greenland  2015             3                            11
# 332          Azerbaijan  1992          1142                          8307
# 278           Australia  1998            86                          2547
# 1695  Equatorial Guinea  2002           336                           495
# 2727             Jordan  2017            27                           984
# 5791     United Kingdom  1991           702                         38841
#
#       Chronic Respiratory Diseases
# 5615                         19173
# 3049                           659
# 1946                           297
# ...

# %%
# circulatory system
'''
Malaria
Cardiovascular Diseases	'''

circulatory_system=df[['Country/Territory','Year','Malaria','Cardiovascular Diseases']]
circulatory_system.sample(10)
# Out:
#        Country/Territory  Year  Malaria  Cardiovascular Diseases
# 83               Algeria  2013        0                    80572
# 2983             Lesotho  2003        0                     3686
# 726             Botswana  2016        4                     3253
# 964               Canada  1994        0                    76928
# 1575  Dominican Republic  2005       32                    17011
# 3019             Liberia  2009     4989                     3718
# 3004             Liberia  1994     4225                     3178
# 2768               Kenya  1995    14104                    17894
# 2089              Greece  2009        0                    47236
# 4094            Pakistan  1997    12339                   225799

# %%
# digestive system
'''
Nutritional Deficiencies
Diarrheal Diseases
Digestive Diseases

'''

digestive_system=df[['Country/Territory','Year','Nutritional Deficiencies','Diarrheal Diseases','Digestive Diseases']]
digestive_system.sample(10)
# Out:
#      Country/Territory  Year  Nutritional Deficiencies  Diarrheal Diseases  \
# 533            Belgium  2013                       340                 855
# 5123             Spain  2013                       388                1053
# 1232      Cook Islands  1992                         0                   1
# 1261        Costa Rica  1991                        36                 136
# 2182              Guam  2012                         3                   5
# 5088       South Sudan  2003                      5973                7112
# 3677           Namibia  2007                       236                 923
# 268            Armenia  2018                         4                  14
# 4885         Singapore  2012                         1                  24
# 913           Cambodia  2003                      1377                3814
#
#       Digestive Diseases
# 533                 5407
# 5123               21266
# 1232                   4
# 1261                 656
# ...

# %%
#Immune system
#HIV/AIDS
Immune_system=df[['Country/Territory','Year','HIV/AIDS']]
Immune_system.sample(10)
# Out:
#      Country/Territory  Year  HIV/AIDS
# 791             Brunei  2001         2
# 938           Cameroon  1998     18125
# 5886           Uruguay  1996       113
# 3017           Liberia  2007      2375
# 3198          Malaysia  2001      2034
# 526            Belgium  2006        68
# 2292            Guyana  2002       411
# 233          Argentina  2013      1747
# 2592            Israel  2002        29
# 2840            Kuwait  2006         3

# %%
#renal system
'''
Chronic Kidney Disease
Diabetes Mellitus
'''
renal_system=df[['Country/Territory','Year','Chronic Kidney Disease','Diabetes Mellitus']]
renal_system.sample(10)
# Out:
#      Country/Territory  Year  Chronic Kidney Disease  Diabetes Mellitus
# 4043            Norway  2013                     763                678
# 6074            Zambia  2004                    1340               1769
# 4649             Samoa  2019                      61                124
# 2116         Greenland  2006                       5                  5
# 2084            Greece  2004                    2837               1101
# 445         Bangladesh  2006                   10222              22127
# 5893           Uruguay  2003                     698                737
# 3708             Nauru  2008                       3                  6
# 5109             Spain  1999                    9219              10140
# 2682             Japan  1993                   22424              10334

# %%
#hepatic system
'''
Cirrhosis and Other Chronic Liver Diseases
Acute Hepatitis
Alcohol Use Disorders
'''
hepatic_system=df[['Country/Territory','Year','Cirrhosis and Other Chronic Liver Diseases','Acute Hepatitis','Alcohol Use Disorders']]
hepatic_system.sample(10)
# Out:
#      Country/Territory  Year  Cirrhosis and Other Chronic Liver Diseases  \
# 1992           Georgia  2002                                        1638
# 4294       Philippines  1994                                        8886
# 880            Burundi  2000                                        1554
# 2970           Lesotho  1990                                         308
# 2066             Ghana  2016                                        5926
# 5903           Uruguay  2013                                         459
# 6094          Zimbabwe  1994                                        1608
# 3379         Mauritius  2009                                         306
# 2948           Lebanon  1998                                         404
# 2361          Honduras  2011                                        2340
#
#       Acute Hepatitis  Alcohol Use Disorders
# 1992                5                     49
# 4294             1118                   1079
# ...

# %%
#other
'''
Fire, Heat, and Hot Substances
Road Injuries
Protein-Energy Malnutrition
Poisonings
Conflict and Terrorism
Environmental Heat and Cold Exposure
Exposure to Forces of Nature
Self-harm
Interpersonal Violence
Drowning
Maternal Disorders
Neonatal Disorders
Neoplasms
'''
other=df[['Country/Territory','Year',"Fire, Heat, and Hot Substances",'Road Injuries',
          "Protein-Energy Malnutrition","Poisonings","Conflict and Terrorism","Environmental Heat and Cold Exposure",
          "Exposure to Forces of Nature","Self-harm","Interpersonal Violence","Drowning","Maternal Disorders",
          "Neonatal Disorders","Neoplasms"]]
other.sample(10)
# Out:
#      Country/Territory  Year  Fire, Heat, and Hot Substances  Road Injuries  \
# 1066              Chad  2002                             358           1737
# 2262     Guinea-Bissau  2002                              53            458
# 6088            Zambia  2018                             323           2258
# 1735           Eritrea  2015                             156           1048
# 4468           Romania  2018                             413           2248
# 2248            Guinea  2018                             401           2299
# 5390          Tanzania  2010                            1138           5118
# 5547             Tonga  2017                               3             10
# 5672            Tuvalu  1992                               0              3
# 4987           Somalia  2015                             570           3236
#
#       Protein-Energy Malnutrition  Poisonings  Conflict and Terrorism  \
# ...
